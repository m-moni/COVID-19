# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import scipy.stats

# %%
data_frame = pd.read_csv('chi_square_data.csv')

# %%
cols = data_frame.columns
#print(cols)
for j in range(len(cols)):
  try:
    g, p, dof, expctd = scipy.stats.chi2_contingency(pd.crosstab(index=data_frame['Hospitalized'],columns=data_frame[cols[j]]))
    print(p)
  except:
    pass
# Out:
# 2.567439971082361e-08
# 9.84116286170854e-45
# 6.549038958872139e-62
# 4.789943170692997e-30
# 1.9378673373158446e-36
# 0.9947656879336173
# 2.8252898957314986e-62
# 9.851179339951199e-22
# 9.552120588451109e-32
# 0.0004499706463024957
# 0.01979011398406949
# 0.0020652667969394837
# 0.35522544429147884
# 0.7509689165881235
# 5.5526363415884724e-08
# 2.523224462289235e-07
# 1.551209852836055e-05
# 2.260995466389501e-07
# 0.0024520458012868528
# 4.499383273394695e-05
# 1.6944036199936248e-06
# 0.09302998816127944
# 2.3537106873908966e-05
# 7.311906679351595e-09
# 3.383109481697672e-18
# 1.2245092266568358e-08
# 0.00033476328153840307
# 0.23217538833479923
# 0.3053378907664435
# 0.0
# 0.8417467695282753
# 1.6393257575566685e-22
# 0.011637145940458643
# 1.31330640669076e-08
# 5.703299955264699e-32
# 0.1816091047862466
# 0.013999772004729256
# 0.11419072892766531
# 0.03002207803167726
# 3.918607876525317e-06
# 4.015324128119542e-13
# 1.4431330756218172e-05
# 7.775056424859429e-11
# ...
